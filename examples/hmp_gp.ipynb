# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pathlib import Path

ROOT = Path("..").resolve()
sys.path.insert(0, str(ROOT / "src"))
# %cd {ROOT}

from lgtm.train import *
from lgtm.utils import get_sobol_indices
from lgtm.utils_plot import *

# %% [markdown]
# Load data and configuration

# %%
cohort = "hmp"

config = importlib.import_module("lgtm.config")
attrs = importlib.import_module(f"scripts.{cohort}_data")
args = getattr(config, "args")

args.name = f"{cohort}-{args.task}-{args.method}"
args.name += f"-L{args.latent_dim}"

# %% [markdown]
# Train model

# %%
results = train1(attrs, args)
model = results["artifacts"]["model"]
torch.save(model, Path("data") / f"{args.name}.pt")

# %%
model = torch.load(Path("data") / f"{args.name}.pt", weights_only=False)

# %% [markdown]
# Visualization

# %%
plt.rcParams.update({
    "figure.figsize": [3.5, 2.625],
    "lines.linewidth": 1,
    "font.family": "serif",
    "font.size": 10,
    "savefig.dpi": 300,
    "savefig.bbox": "tight",
    "pdf.fonttype": 42
})

# %%
model.eval()
B = model.get_beta()
dataset = MetagenomeDataset(attrs.y, attrs.x_num, attrs.x_cat)
X = dataset[:]["x"]
Y = dataset[:]["y"]
X_mask = dataset[:]["x_mask"]
theta = model.get_theta(X, Y, X_mask)

# %%
# compute Sobol' index and plot the heatmap
def get_theta(x):
    x = np.transpose(x)
    x = torch.Tensor(x)
    theta = model.get_theta(x)
    f_eval = np.transpose(theta)
    return f_eval

sobol_result, var_y = get_sobol_indices(get_theta, dataset, attrs)

plt.rcParams.update({"font.size": 14})
fig_si, _ = plot_si_heatmap(theta, sobol_result, var_y, attrs.x_cols)

# %%
# plot taxonomic composition of topics
fig_topics, _, = plot_topics(B, theta, attrs.features)

# %%
# for each latent dimension: plot the topic, latent functions of additive components, and topic proportions of samples
plt.rcParams.update({"font.size": 9})
l_sorted = np.argsort(np.mean(theta, axis=0))[::-1]
for cnt, l in enumerate(l_sorted):
    fig_1, _ = plot_topic(B, theta, cnt, l, attrs.features)
    fig_2, _ = plot_gp(model, dataset, attrs, cnt, l, sobol_result)
    fig_3, _ = plot_latent(model, attrs, theta, l)
